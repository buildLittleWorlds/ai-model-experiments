# %% [markdown]
# # Session 12: Reflection and Level 3 Preparation
# ## Share What You Built
#
# **Session Length:** 2 hours
#
# **Today's Mission:** Present your project, reflect on your growth across 12 sessions, and look ahead to what comes next.
#
# ### Session Outline
# | Time | Activity |
# |------|----------|
# | 0:00-0:50 | Part 1: Presentations |
# | 0:50-1:10 | Part 2: Course Reflection |
# | 1:10-1:40 | Part 3: Bridge to Level 3 |
# | 1:40-2:00 | Portfolio wrap-up + celebration |
#
# ### Key Vocabulary
# | Term | Definition |
# |------|-----------|
# | Demo | Showing your project to others with live examples |
# | Peer Feedback | Constructive input from classmates |
# | Self-Assessment | Honestly evaluating your own growth |
# | Research Question | A question you could investigate using experiments and data |
# | Portfolio | A collection of work that shows what you can do |
# | Model Card | A document on the Hub describing a model's training data, intended use, and limitations |
#
# ---

# %% [markdown]
# ## Part 1: Presentations (0:00-0:50)
#
# Each student gets approximately 8 minutes: 5 for the demo, 3 for questions.
#
# ### Presentation Order
#
# | Order | Name | Project |
# |-------|------|---------|
# | 1 | | |
# | 2 | | |
# | 3 | | |
# | 4 | | |
# | 5 | | |
# | 6 | | |
#
# ### Demo Script Template
#
# Use this structure for your presentation:
#
# **Introduction (30 seconds):**
# "My project is called _______. It helps _______ to _______."
#
# **Demo Example 1 -- Simple Case (90 seconds):**
# Show a straightforward input and output. Explain what the model is doing.
#
# **Demo Example 2 -- Interesting Case (90 seconds):**
# Show something more complex or surprising. Highlight what your tool does well.
#
# **Demo Example 3 -- Edge Case (60 seconds):**
# Show where your tool struggles. Explain WHY it struggles (connect to Sessions 7-8).
#
# **Closing (30 seconds):**
# "The hardest part was _______. If I had more time, I would add _______."
#
# ---

# %% [markdown]
# > **INSTRUCTOR NOTE:** Keep time strictly. Use a visible timer. After each presentation, invite 2-3 questions from the group. Encourage specific, constructive questions like "What would happen if you gave it [input]?" rather than just "that's cool."
#
# ### Peer Feedback Notes
#
# As you watch each presentation, take notes:
#
# ---
#
# **Presenter 1:**
# - Project name:
# - What they did well:
# - A question I have:
#
# **Presenter 2:**
# - Project name:
# - What they did well:
# - A question I have:
#
# **Presenter 3:**
# - Project name:
# - What they did well:
# - A question I have:
#
# **Presenter 4:**
# - Project name:
# - What they did well:
# - A question I have:
#
# **Presenter 5:**
# - Project name:
# - What they did well:
# - A question I have:
#
# **Presenter 6:**
# - Project name:
# - What they did well:
# - A question I have:
#
# ---

# %% [markdown]
# ## Part 2: Course Reflection (0:50-1:10)
#
# ### Skills Self-Assessment
#
# Rate yourself honestly: 1 = beginner, 5 = confident.
#
# | Skill | Session 1 | Now |
# |-------|-----------|-----|
# | Using AI tools (Hugging Face Spaces, etc.) | | |
# | Running code in Google Colab | | |
# | Using AI assistants to help write code | | |
# | Understanding what AI code does | | |
# | Combining multiple AI models | | |
# | Debugging when things don't work | | |
# | Explaining AI concepts to others | | |
# | Using GitHub | | |
# | Reading model cards on the Hub | | |

# %% [markdown]
# ### Vocabulary Recap
#
# You learned these terms over 12 sessions. You can now use them accurately -- and that matters.
#
# | Term | Learned In | Meaning |
# |------|-----------|---------|
# | Artificial Intelligence | Session 1 | Computers doing tasks that usually require human intelligence |
# | Model | Session 1 | A program that learned patterns from examples |
# | Input / Output | Session 1 | What goes into and comes out of a model |
# | Pipeline (HF) | Session 2 | A ready-to-use model wrapper in Hugging Face |
# | CLEAR Framework | Session 3 | Context, Language, Explain, Ask, Requirements |
# | Supervised Learning | Session 4 | Learning from labeled examples |
# | Pre-trained Model | Session 4 | A model someone else already trained on large data |
# | Hyperparameters | Session 5 | Settings YOU control (temperature, top-p, etc.) |
# | Temperature | Session 5 | Controls creativity vs. predictability in generation |
# | Confidence Score | Session 6 | How sure the model is (not how correct it is) |
# | False Positive / Negative | Session 6 | Two types of model errors |
# | Domain Shift | Session 7 | When input data differs from training data |
# | Overfitting | Session 7 | Too good at training data, too bad at new data |
# | Generalization | Session 7 | Model works on data it hasn't seen before |
# | Bias | Session 8 | Systematic patterns in model mistakes |
# | Training Data Bias | Session 8 | When training data doesn't represent everyone equally |
# | Uncertainty | Session 8 | When the model isn't sure (but might not show it) |
# | Pipeline (system) | Session 9 | Chaining multiple models together |
# | Error Cascade | Session 9 | When one model's mistake makes downstream models worse |
# | Prompt Engineering | Session 10 | Designing inputs to get better outputs |
# | MVP | Session 11 | Minimum Viable Product -- simplest version that works |
# | Iteration | Session 11 | Improving through repeated cycles of testing and changing |
#
# **You started this course knowing what AI tools look like from the outside. You are leaving knowing how they work on the inside.**

# %% [markdown]
# ### Personal Reflection
#
# **The most important thing I learned about AI:**
#
# **The most surprising thing I discovered:**
#
# **The hardest part of the course was:**
#
# **I overcame challenges by:**
#
# **What I'm most proud of building:**
#
# ---

# %% [markdown]
# ## Part 3: Bridge to Level 3 (1:10-1:25)
#
# ### You Have Been Doing Research All Semester
#
# Think about what you did:
# - You **formed hypotheses** ("I think the Twitter model will handle slang better")
# - You **designed experiments** (paired-sentence bias tests, domain shift comparisons)
# - You **collected evidence** (model outputs, confidence scores, comparison tables)
# - You **drew conclusions** ("the model's training data explains its blind spots")
# - You **documented results** (your project README, your observation tables)
#
# That is the scientific method. You have been doing research.
#
# ### What Level 3 Looks Like
#
# In Level 2, the question was: **"Try this model and see what happens."**
#
# In Level 3, the question will be: **"What do YOU want to investigate?"**
#
# Instead of following guided experiments, you will:
# - **Choose a research question** about AI
# - **Design your own experiments** to answer it
# - **Collect and analyze data** systematically
# - **Write up your findings** like a real researcher
# - **Present your research** to the group
#
# ### Example Research Questions
#
# These are the kinds of questions Level 3 students might investigate:
#
# - "Do sentiment models treat different languages or dialects fairly?"
# - "How much does training data size affect model accuracy?"
# - "Can zero-shot classification replace fine-tuned models for specific tasks?"
# - "How do different prompting strategies affect text generation quality?"
# - "What happens when you chain 5+ models together -- does error compound predictably?"
#
# ### Your Research Question

# %% [markdown]
# > **INSTRUCTOR NOTE:** Go around the group. Each student shares one question about AI they would want to answer if they had the tools and time. Write them down -- these feed directly into Level 3 planning.
#
# **My research question:**
#
# **Why this interests me:**
#
# **How I might investigate it:**
#
# ---

# %% [markdown]
# > **READ THE MODEL CARD: Reflect on a Model You Used**
# >
# > You have used many models across 12 sessions. Pick the one that was **most important to your project** and do a final deep read of its model card.
# >
# > Go to `huggingface.co/<model-id>` (e.g., [huggingface.co/cardiffnlp/twitter-roberta-base-sentiment-latest](https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment-latest)) and answer:
# >
# > 1. **Who created it and why?** (Research lab? Company? What problem were they solving?)
# > 2. **What data was it trained on?** (How much? From where? When was it collected?)
# > 3. **What are the stated limitations?** (Does the model card warn about specific failure modes?)
# > 4. **Did you experience those limitations in your project?** (Connect to your Sessions 7-8 experiments)
# > 5. **What would you want to know that the model card does NOT tell you?**
# >
# > This is how professionals evaluate AI tools -- not just "does it work?" but "why does it work, and where will it fail?"
#
# **Model I am reviewing:**
#
# **Who created it and why:**
#
# **Training data:**
#
# **Stated limitations:**
#
# **Did I see those limitations?**
#
# **What the model card doesn't tell me:**
#
# ---

# %% [markdown]
# > **FIND A MODEL: Explore a New Task for Level 3**
# >
# > In Level 3, you will choose your own research direction. Start browsing now -- what tasks on the Hub look interesting that we did NOT cover in this course?
# >
# > Browse tasks you have not tried:
# >
# > - **Translation:** [huggingface.co/models?pipeline_tag=translation&sort=downloads](https://huggingface.co/models?pipeline_tag=translation&sort=downloads)
# > - **Fill-mask (word prediction):** [huggingface.co/models?pipeline_tag=fill-mask&sort=downloads](https://huggingface.co/models?pipeline_tag=fill-mask&sort=downloads)
# > - **Table question answering:** [huggingface.co/models?pipeline_tag=table-question-answering&sort=downloads](https://huggingface.co/models?pipeline_tag=table-question-answering&sort=downloads)
# > - **Audio classification:** [huggingface.co/models?pipeline_tag=audio-classification&sort=downloads](https://huggingface.co/models?pipeline_tag=audio-classification&sort=downloads)
# > - **All tasks:** [huggingface.co/tasks](https://huggingface.co/tasks)
# >
# > Pick one task you have never tried. Read the top model's model card. Could this be part of a Level 3 research question?

# %% [markdown]
# ## Portfolio Wrap-Up + Celebration (1:40-2:00)
#
# ### Your Portfolio Summary
#
# **My GitHub Repository:** (URL)
#
# **What's in my portfolio:**
# - [ ] Session exploration notes
# - [ ] Model experiments from Sessions 2-8
# - [ ] Pipeline work from Session 9
# - [ ] Final project notebook
# - [ ] README describing my learning journey
#
# ### Project Summary for Applications
#
# Use this when talking about your work:
#
# ```
# Project: [Name]
#
# I built [what it does] using [AI technologies] in Python with Hugging Face.
# The project [solves what problem / enables what capability] for [who].
#
# Technical highlights:
# - Used [model/technique 1] to [do what]
# - Combined [X models] to [achieve what]
# - Learned to identify [domain shift / bias / error cascades] in AI systems
#
# This project taught me [biggest learning].
# ```

# %% [markdown]
# ### Continue Learning
#
# **Free resources to explore:**
# - [Hugging Face Course](https://huggingface.co/learn) -- Free NLP course
# - [Hugging Face Tasks](https://huggingface.co/tasks) -- Explore every task type the Hub supports
# - [fast.ai](https://www.fast.ai/) -- Practical deep learning
# - [Kaggle Learn](https://www.kaggle.com/learn) -- Data science tutorials
#
# **Ideas for your next project:**
# - Improve your current project with more features
# - Build a web interface using Gradio
# - Try a completely new AI task from the Hub
# - Collaborate with a classmate on something bigger
#
# ### Stay Connected
#
# - Keep your GitHub active -- commit regularly
# - Share what you build on your Hugging Face profile
# - Start following AI researchers whose work interests you

# %% [markdown]
# ---
#
# ## Congratulations!
#
# You have completed the Youth Horizons AI Researcher Program -- Level 2.
#
# Over 12 sessions, you learned to:
# - **Explore** AI tools and understand the INPUT --> MODEL --> OUTPUT pattern
# - **Run** AI models with real Python code
# - **Control** models through hyperparameters and prompt engineering
# - **Evaluate** models critically -- confidence, accuracy, bias, domain shift
# - **Chain** models into multi-model systems
# - **Build** your own AI-powered tool from scratch
# - **Navigate** the Hugging Face Hub to find, compare, and understand models
# - **Present** technical work to others
#
# These are real skills. The models you used are the same ones powering products at Google, Microsoft, and thousands of startups. The concepts you learned -- bias, generalization, error cascades, prompt engineering -- are what professional AI engineers think about every day.
#
# **Keep building. Keep questioning. Keep learning.**
#
# ---
#
# *Youth Horizons AI Researcher Program -- Level 2*
#
# *Instructor: Dr. Daniel Plate*
